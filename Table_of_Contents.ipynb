# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@300;400;600&display=swap');
#
# body {
#     --ibm-blue: #0f62fe;
#     --dark-blue: #2756ad;
#     --path-red: #cf1a4d;
# }
#
# h1,h2,h3,h4,p {
#     font-family: "IBM Plex Sans";
#     color: rgba(0,0,0,.7) !important;
# }
# h1,h2 {
#     margin: 60px 0 10px 0 !important;
# }
# h3,h4 {
#     margin: 40px 0 10px 0 !important;
# }
# h1 {
#     font-size: 2.8em !important;
#     font-weight: 300 !important;
# }
# h2 {
#     font-size: 2.2em !important;
#     color: var(--dark-blue) !important;
# }
# h3 {
#     font-size: 1.5em !important;
#     font-weight: 600 !important;
# /*     font-style: italic !important; */
# }
# h4 {
#     font-size: 1.2em !important;
#     text-decoration: underline;
#     text-decoration-color: rgba(0,0,0,.2);
#     text-underline-offset: 2px;
# }
# h1 + h2,
# h1 + h3,
# h1 + h4,
# h2 + h3,
# h2 + h4,
# h3 + h4 {
#     margin-top: 30px !important;
# }
# /* h1:first-child,
# h2:first-child {
#     margin-top: 40px !important;
# } */
# /* h3:first-child,
# h4:first-child {
#     margin-top: 20px !important;
# } */
# span + h3 {
#     margin-top: 20px !important;
#     color: red !important;
# }
# p, ul, ol {
#     max-width: 700px !important;
# }
#
#
# /**
#  * Paths
#  */
#
# span.path {
#     color: var(--path-red);
#     font-style: italic;
#     padding: 0 5px;
# }
#
# /**
#  * Command instructions
#  */
#
# pre {
#     margin: 0 !important;
# }
# pre.cmd,
# pre code {
#     display: block;
#     color: #eec !important;
#     background-color: #444 !important;
#     padding: 20px !important;
#     margin: 10px 0 !important;
#     border-radius: 3px;
# }
#
#
#
# /**
#  * Page Banner
#  */
#
# .banner {
#     font-family: "IBM Plex Sans";
#     width: 100%;
#     height: 140px;
#     color: white;
#     font-size: 30px;
#     line-height: 30px;
#     text-align: right;
#     padding: 20px;
#     position: relative;
#     z-index: 1;
#     box-sizing: border-box;
#     display: flex;
#     flex-direction: column-reverse;
#     font-weight: 300;
# }
# .banner::after {
#     content: '';
#     position: absolute;
#     bottom: 0;
#     left: 0;
#     z-index: -1;
#     width: 100%;
#     height: 100%;
#     filter: brightness(0.5);
# }
# .banner::before {
#     content: '';
#     position: absolute;
#     left: 0;
#     right: 0;
#     z-index: 1;
#     height: 2px;
#     bottom: -6px;
#     background: var(--ibm-blue);
#
# }
# .banner b {
#     display: block;
#     font-weight: 600;
#     font-size: 14px;
# }
# .banner b span {
#     font-weight: 400;
# }
# .banner b span::before {
#     content: ' / ';
#     margin: 0 5px;
# }
#
# </style>

# %% [markdown]
# <!-- Header banner -->
# <div class="banner"><div>OpenAD tutorial Menu</div><b>OpenAD <span>Tutorial</span></b></div>

# %% [markdown]
# # Welcome to the Open Accelerated Discovery Client

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">Accelerated Discovery Client Introduction</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              This will demonstrate how to work with the OpenAD Client through Notebooks.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block;"src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./Common_Client_Intro.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">Using Shortcuts and Molecule Viewer</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              Learn how to use the onead shortcuts and viewer.
#             <img style="float:right; width: 125px; height: 100px;"src="./media/genai.png" >
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block; "src="./media/clock.png">&nbsp;5min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./shortcuts_viewer.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">BMFM Protein and Small Molecule Demo</div>
#         <div style="height: 125px"><p style="font-size: 14px">
#              Learn how to work with the New BMFM Protein and Small Molecule Inference Model capabilites
#             <img style="float:right; width: 125px; height: 100px;"src="./media/genai.png" >
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#             <img style="display: inline-block; "src="./media/clock.png">&nbsp;10min
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
#              <a href="./BMFM_HOL.ipynb">
#                  <img style="display: inline-block;"src="./media/arrowblue.png"></a>
#         </div>
#     </td>
#
# </table>
# </div>

# %% [markdown]
# #### Questions and Comments: Phil Downey [phil.downey1@ibm.com]
